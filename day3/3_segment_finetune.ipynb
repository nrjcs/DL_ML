# %% [markdown]
# # Image Segmentation
#
# ![segmentation](http://vladlen.info/wp-content/uploads/FSO-1.jpg)

# %% [markdown]
# # Get custom dataset from Github

# %%
# !git clone https://github.com/lim-eren/CDnet2014.git
# Out:
# fatal: destination path 'CDnet2014' already exists and is not an empty directory.

# %%
# !ls */train/*
# Out:
# CDnet2014/train/x:
# in000685.jpg  in000853.jpg  in001057.jpg  in001217.jpg	in001537.jpg
# in000765.jpg  in000873.jpg  in001077.jpg  in001364.jpg	in001613.jpg
# in000789.jpg  in000896.jpg  in001104.jpg  in001416.jpg	in001636.jpg
# in000809.jpg  in000925.jpg  in001125.jpg  in001477.jpg	in001657.jpg
# in000832.jpg  in001009.jpg  in001189.jpg  in001517.jpg	in001680.jpg
#
# CDnet2014/train/y:
# gt000685.png  gt000853.png  gt001057.png  gt001217.png	gt001537.png
# gt000765.png  gt000873.png  gt001077.png  gt001364.png	gt001613.png
# gt000789.png  gt000896.png  gt001104.png  gt001416.png	gt001636.png
# gt000809.png  gt000925.png  gt001125.png  gt001477.png	gt001657.png
# gt000832.png  gt001009.png  gt001189.png  gt001517.png	gt001680.png

# %% [markdown]
# # Use dataset uploaded to Google Drive
#
# Download this .zip file and upload to your Google Drive https://goo.gl/ZXezxB

# %% [markdown]
# ## Authenticate Colab to access Google drive

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ## Download our file to Jupyter

# %%
download = drive.CreateFile({'id':'18vvShz5rOCWNF6Eo5AQ3PgD_z5V7oUpG'})
download.GetContentFile('CDnet2014.zip')
# !unzip CDnet2014.zip
# Out:
# Archive:  CDnet2014.zip
# replace CDnet2014/train/y/gt001680.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#  extracting: CDnet2014/train/y/gt001680.png
#  extracting: CDnet2014/train/y/gt001657.png
#   inflating: CDnet2014/train/y/gt001636.png
#  extracting: CDnet2014/train/y/gt001613.png
#   inflating: CDnet2014/train/y/gt001537.png
#   inflating: CDnet2014/train/y/gt001517.png
#  extracting: CDnet2014/train/y/gt001477.png
#  extracting: CDnet2014/train/y/gt001416.png
#  extracting: CDnet2014/train/y/gt001364.png
#  extracting: CDnet2014/train/y/gt001217.png
#  extracting: CDnet2014/train/y/gt001189.png
#  extracting: CDnet2014/train/y/gt001125.png
#  extracting: CDnet2014/train/y/gt001104.png
#   inflating: CDnet2014/train/y/gt001077.png
#   inflating: CDnet2014/train/y/gt001057.png
#   inflating: CDnet2014/train/y/gt001009.png
#  extracting: CDnet2014/train/y/gt000925.png
#   inflating: CDnet2014/train/y/gt000896.png
#   inflating: CDnet2014/train/y/gt000873.png
#  extracting: CDnet2014/train/y/gt000853.png
#  extracting: CDnet2014/train/y/gt000832.png
#  extracting: CDnet2014/train/y/gt000809.png
#  extracting: CDnet2014/train/y/gt000789.png
#  extracting: CDnet2014/train/y/gt000765.png
#  extracting: CDnet2014/train/y/gt000685.png
#   inflating: CDnet2014/train/x/in001680.jpg
#   inflating: CDnet2014/train/x/in001657.jpg
#   inflating: CDnet2014/train/x/in001636.jpg
#   inflating: CDnet2014/train/x/in001613.jpg
#   inflating: CDnet2014/train/x/in001537.jpg
#   inflating: CDnet2014/train/x/in001517.jpg
#   inflating: CDnet2014/train/x/in001477.jpg
#   inflating: CDnet2014/train/x/in001416.jpg
#   inflating: CDnet2014/train/x/in001364.jpg
#   inflating: CDnet2014/train/x/in001217.jpg
#   inflating: CDnet2014/train/x/in001189.jpg
#   inflating: CDnet2014/train/x/in001125.jpg
#   inflating: CDnet2014/train/x/in001104.jpg
#   inflating: CDnet2014/train/x/in001077.jpg
#   inflating: CDnet2014/train/x/in001057.jpg
#   inflating: CDnet2014/train/x/in001009.jpg
#   inflating: CDnet2014/train/x/in000925.jpg
#   inflating: CDnet2014/train/x/in000896.jpg
#   inflating: CDnet2014/train/x/in000873.jpg
#   inflating: CDnet2014/train/x/in000853.jpg
#   inflating: CDnet2014/train/x/in000832.jpg
#   inflating: CDnet2014/train/x/in000809.jpg
#   inflating: CDnet2014/train/x/in000789.jpg
#   inflating: CDnet2014/train/x/in000765.jpg
#   inflating: CDnet2014/train/x/in000685.jpg
#   inflating: CDnet2014/test/y/gt001324.png
#   inflating: CDnet2014/test/y/gt001300.png
#   inflating: CDnet2014/test/y/gt001272.png
#  extracting: CDnet2014/test/y/gt001235.png
#  extracting: CDnet2014/test/y/gt001177.png
#   inflating: CDnet2014/test/y/gt000940.png
#  extracting: CDnet2014/test/y/gt000918.png
#  extracting: CDnet2014/test/y/gt000847.png
#  extracting: CDnet2014/test/y/gt000727.png
#  extracting: CDnet2014/test/y/gt000700.png
#   inflating: CDnet2014/test/x/in001324.jpg
#   inflating: CDnet2014/test/x/in001300.jpg
#   inflating: CDnet2014/test/x/in001272.jpg
#   inflating: CDnet2014/test/x/in001235.jpg
#   inflating: CDnet2014/test/x/in001177.jpg
#   inflating: CDnet2014/test/x/in000940.jpg
#   inflating: CDnet2014/test/x/in000918.jpg
#   inflating: CDnet2014/test/x/in000847.jpg
#   inflating: CDnet2014/test/x/in000727.jpg
#   inflating: CDnet2014/test/x/in000700.jpg

# %% [markdown]
# ##  Add this code snippet to obtain reproducible results across machines

# %%
# Run it to obtain reproducible results across machines (from keras.io)
from __future__ import print_function
import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
rn.seed(12345)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K
tf.set_random_seed(1234)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# %% [markdown]
# ## Create a function to load data

# %%
import glob
from keras.preprocessing import image as kImage

def getData(dataset_dir):
    X_list= sorted(glob.glob(os.path.join(dataset_dir, 'x','*.jpg')))
    Y_list = sorted(glob.glob(os.path.join(dataset_dir, 'y' ,'*.png')))
    
    X= []
    Y= []
    for i in range(len(X_list)):
        # Load input image
        x = kImage.load_img(X_list[i])
        x = kImage.img_to_array(x)
        X.append(x)
        
        # Load ground-truth label and encode it to label 0 and 1
        x = kImage.load_img(Y_list[i], color_mode = "grayscale")
        x = kImage.img_to_array(x)
        x /= 255.0
        x = np.floor(x)
        Y.append(x)
    X = np.asarray(X)
    Y = np.asarray(Y)
    
    # Shuffle the training data
    idx = list(range(X.shape[0]))
    np.random.shuffle(idx)
    X = X[idx]
    Y = Y[idx]
    return X, Y

# %% [markdown]
# ## Vanilla encoder-decoder network

# %%
import keras
from keras.models import Model
from keras.layers import Deconv2D, Input

def initModel():
    ### Encoder
    net_input = Input(shape=(240,320,3))
    vgg16 = keras.applications.vgg16.VGG16(include_top=False, weights='imagenet', input_tensor=net_input)
    for layer in vgg16.layers[:17]:
      layer.trainable = False
    
    x = vgg16.layers[-2].output # 2nd layer from the last, block5_conv3
    
    ### Decoder
    x = Deconv2D(256, (3,3), strides=(2,2), activation='relu', padding='same')(x)
    x = Deconv2D(128, (3,3), strides=(2,2), activation='relu', padding='same')(x)
    x = Deconv2D(64, (3,3), strides=(2,2), activation='relu', padding='same')(x)
    x = Deconv2D(32, (3,3), strides=(2,2), activation='relu', padding='same')(x)
    x = Deconv2D(1, (1,1), activation='sigmoid', padding='same')(x)
    
    model = Model(inputs=vgg16.input, outputs=x)
    model.compile(loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.RMSprop(lr=5e-4), metrics=['accuracy'])
    return model

# %% [markdown]
# ## Load data

# %%
# load data
dataset_path = os.path.join('CDnet2014', 'train')
X, Y = getData(dataset_path)

# %% [markdown]
# ## Display dataset

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
for i in range(1,6,2):
  plt.tight_layout()
  plt.subplot(3,2,i)
  plt.imshow(X[i,:,:,:], interpolation='none')
  plt.xticks([])
  plt.yticks([])
  plt.subplot(3,2,i+1)
  plt.imshow(Y[i,:,:,0], interpolation='none')
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ## Train network

# %%
# init the model
model = initModel()

# print model arch
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 240, 320, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 240, 320, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 240, 320, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 120, 160, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 120, 160, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 120, 160, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 60, 80, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 60, 80, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 60, 80, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 60, 80, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 30, 40, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 30, 40, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 30, 40, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 30, 40, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 15, 20, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 15, 20, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 15, 20, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 15, 20, 512)       2359808
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 30, 40, 256)       1179904
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 60, 80, 128)       295040
# _________________________________________________________________
# conv2d_transpose_8 (Conv2DTr (None, 120, 160, 64)      73792
# _________________________________________________________________
# conv2d_transpose_9 (Conv2DTr (None, 240, 320, 32)      18464
# _________________________________________________________________
# conv2d_transpose_10 (Conv2DT (None, 240, 320, 1)       33
# =================================================================
# Total params: 16,281,921
# Trainable params: 3,927,041
# Non-trainable params: 12,354,880
# _________________________________________________________________

# %%
early = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=10)
reduce = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)

model.fit(X, Y, batch_size=1, epochs=100, verbose=2, validation_split=0.2, callbacks=[reduce, early], shuffle=True)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Train on 20 samples, validate on 5 samples
# Epoch 1/100
#  - 4s - loss: 0.2406 - acc: 0.9035 - val_loss: 0.1077 - val_acc: 0.9073
# Epoch 2/100
#  - 1s - loss: 0.0972 - acc: 0.9410 - val_loss: 0.0716 - val_acc: 0.9729
# Epoch 3/100
#  - 1s - loss: 0.0719 - acc: 0.9719 - val_loss: 0.0473 - val_acc: 0.9792
# Epoch 4/100
#  - 1s - loss: 0.0580 - acc: 0.9757 - val_loss: 0.0514 - val_acc: 0.9772
# Epoch 5/100
#  - 1s - loss: 0.0457 - acc: 0.9813 - val_loss: 0.0395 - val_acc: 0.9831
# Epoch 6/100
#  - 1s - loss: 0.0444 - acc: 0.9821 - val_loss: 0.0433 - val_acc: 0.9825
# Epoch 7/100
#  - 1s - loss: 0.0377 - acc: 0.9839 - val_loss: 0.0424 - val_acc: 0.9815
# Epoch 8/100
#  - 1s - loss: 0.0338 - acc: 0.9861 - val_loss: 0.0405 - val_acc: 0.9838
# Epoch 9/100
#  - 1s - loss: 0.0264 - acc: 0.9886 - val_loss: 0.0580 - val_acc: 0.9808
# Epoch 10/100
#  - 1s - loss: 0.0305 - acc: 0.9876 - val_loss: 0.0460 - val_acc: 0.9826
# Epoch 11/100
#  - 1s - loss: 0.0181 - acc: 0.9926 - val_loss: 0.0422 - val_acc: 0.9844
# Epoch 12/100
#  - 1s - loss: 0.0156 - acc: 0.9935 - val_loss: 0.0446 - val_acc: 0.9844
# Epoch 13/100
#  - 1s - loss: 0.0138 - acc: 0.9942 - val_loss: 0.0463 - val_acc: 0.9847
# Epoch 14/100
#  - 1s - loss: 0.0127 - acc: 0.9948 - val_loss: 0.0486 - val_acc: 0.9849
# Epoch 15/100
#  - 1s - loss: 0.0114 - acc: 0.9953 - val_loss: 0.0532 - val_acc: 0.9847

# %% [markdown]
# ## Save model

# %%
model.save('my_model.h5')
model_file = drive.CreateFile({'title' : 'my_model.h5'})
model_file.SetContentFile('my_model.h5')
model_file.Upload()

# load model
# model = load_model('my_model.h5')

# %% [markdown]
# ## Test our model

# %%
# load test data
dataset_path = os.path.join('CDnet2014', 'test')
X, Y = getData(dataset_path)
# predict
pred = model.predict(X, verbose=0, batch_size=1)
print(tf.Session().run(K.mean(K.equal(Y, K.round(pred)))))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image.py:492: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 0.9892799

# %% [markdown]
# ## View our results

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

idx = 2 # image index that you want to display

img = np.empty(3, dtype=object)
img[0] = X[idx]
img[1] = Y[idx].reshape(Y[idx].shape[0],Y[idx].shape[1])
img[2] = pred[idx].reshape(pred[idx].shape[0],pred[idx].shape[1])
title = ['input', 'ground-truth', 'result']
for i in range(3):
  plt.subplot(1, 3, i+1)
  if i==0:
    plt.imshow(img[i].astype('uint8'))
  else:
    plt.imshow(img[i], cmap='gray')
  
  plt.axis('off')
  plt.title(title[i])
plt.show()

# %% [markdown]
# # Exercise for you
#
# Design a image segmentation model for [semantic dataset](http://www.ntu.edu.sg/home/asjfcai/Benchmark_Website/Semantic%20dataset100.zip).
#
#
# ![semantic](http://www.ntu.edu.sg/home/asjfcai/Benchmark_Website/semantic-example.png =600x)
#
#
#
# Use the same above code and modify to this problem.
